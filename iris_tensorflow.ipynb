# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Charger les données
df = pd.read_csv("Iris.csv")

# Séparer les caractéristiques et la cible
X = df.drop(columns=["Species"])
y = df["Species"]

# Diviser les données en ensembles d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Définir l'architecture du modèle
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(3, activation='softmax')  # 3 classes dans Iris dataset
])

# Encoder les étiquettes de classe en entiers
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Compiler le modèle
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # Pour la classification multi-classe
              metrics=['accuracy'])

# Entraîner le modèle
model.fit(X_train, y_train_encoded, epochs=100, batch_size=10, validation_split=0.2)

# Évaluer le modèle sur les données de test
loss, accuracy = model.evaluate(X_test, y_test_encoded)
print(f"Test Accuracy: {accuracy}")


# Faire des prédictions sur de nouvelles données
# Assurez-vous de fournir de nouvelles données dans le même format que vos données d'entraînement et de test
# Par exemple : predictions = model.predict(X_new_data)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 29ms/step - loss: 5.8618 - accuracy: 0.2812 - val_loss: 1.5412 - val_accuracy: 0.2917
# Epoch 2/100
# 10/10 [==============================] - 0s 5ms/step - loss: 2.9238 - accuracy: 0.3854 - val_loss: 0.9223 - val_accuracy: 0.2500
# Epoch 3/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.5382 - accuracy: 0.4479 - val_loss: 1.3513 - val_accuracy: 0.6667
# Epoch 4/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1149 - accuracy: 0.5417 - val_loss: 1.1040 - val_accuracy: 0.4583
# Epoch 5/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.8826 - accuracy: 0.5417 - val_loss: 0.6517 - val_accuracy: 0.7083
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7617 - accuracy: 0.6667 - val_loss: 0.7008 - val_accuracy: 0.6250
# Epoch 7/100
# ...
